# %%
import numpy as np

# %%
arr=np.array([1,2,3,4])
print(arr,type(arr))
# Out:
# [1 2 3 4] <class 'numpy.ndarray'>

# %%
arr1=np.zeros((2,3))
arr2=np.ones((1,1))
print(arr2,arr2.shape)            
print(arr1,arr1.shape)
# Out:
# [[1.]] (1, 1)
# [[0. 0. 0.]
#  [0. 0. 0.]] (2, 3)

# %%
arr=np.array([1,2,3,4])
print(arr.shape)
print(arr.size)
print(arr.dtype)
print(arr.ndim)
# Out:
# (4,)
# 4
# int64
# 1
