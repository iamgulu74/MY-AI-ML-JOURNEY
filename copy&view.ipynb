# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])
sub_list=arr[1:3]
sub_list[0]=12
print(sub_list)
print(arr)
# Out:
# [12  3]
# [ 1 12  3  4  5]

# %%
num=[1,2,3,4,5]
sub_lis=num[1:3]
sub_lis[0]=12
print(sub_list)
print(num)
# Out:
# [12  3]
# [1, 2, 3, 4, 5]
