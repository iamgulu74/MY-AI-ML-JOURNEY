# %%
import pandas as pd

# %%
info={
    "name": ["gulu","jasaswi","das"],
    "cgpa": [9.0,8.8,9.3]
}
dta= pd.DataFrame(info)
print(dta)
# Out:
#       name  cgpa
# 0     gulu   9.0
# 1  jasaswi   8.8
# 2      das   9.3

# %%
s=pd.Series([9,2,3,4])
print(s)
print(type(s))
# Out:
# 0    9
# 1    2
# 2    3
# 3    4
# dtype: int64
# <class 'pandas.core.series.Series'>
